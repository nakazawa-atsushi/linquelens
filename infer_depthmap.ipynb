# %%
# コントラスト法で奥行きを求める
import json
import glob
import cv2
import os, sys
import gzip
import numpy as np
import dotenv
import argparse
import matplotlib.pyplot as plt

# %%
# compute RMS contract of im
def RMS_contrast(im):
    img_grey = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    contrast = img_grey.std()

    return contrast

# compute Michelson contrast
def Michelson_contrast(im):
    Y = cv2.cvtColor(im, cv2.COLOR_BGR2YUV)[:,:,0]
    
    # compute min and max of Y
    min = np.min(Y)
    max = np.max(Y)

    # compute contrast
    contrast = (max-min)/(max+min)

    return contrast

# %%
if __name__ == '__main__':
    DIR = 'data/202410041747-new'
    
    N_IMG = 400
    PSIZE = 65
    width = 1600
    height = 1200
    STEP = 5

    # contrast values
    cvalues = []
    # focus values
    fvalues = []

    files = glob.glob(os.path.join(DIR,'*.bmp'))

    for fn in files:
        im = cv2.imread(fn)
        if im is None:
            continue

        fvalue = int(os.path.splitext(os.path.basename(fn))[0])
        fvalues.append(fvalue)
        print("image", fn, "fvalue", fvalue)
        
        cvalue = []
        for y in range(0,height-PSIZE,STEP):
            for x in range(0,width-PSIZE,STEP):
                patch = im[y:(y+PSIZE),x:(x+PSIZE),:]
                cvalue.append(RMS_contrast(patch))
        cvalue = np.array(cvalue)
        cvalue = cvalue.reshape((int((height-PSIZE)/STEP),int((width-PSIZE)/STEP)))
        cvalues.append(cvalue)
# Out:
# image data/202410041747-new\10000.bmp fvalue 10000
# image data/202410041747-new\10050.bmp fvalue 10050
# image data/202410041747-new\10100.bmp fvalue 10100
# image data/202410041747-new\10150.bmp fvalue 10150
# image data/202410041747-new\10200.bmp fvalue 10200
# image data/202410041747-new\10250.bmp fvalue 10250
# image data/202410041747-new\10300.bmp fvalue 10300
# image data/202410041747-new\10350.bmp fvalue 10350
# image data/202410041747-new\10400.bmp fvalue 10400
# image data/202410041747-new\10450.bmp fvalue 10450
# image data/202410041747-new\10500.bmp fvalue 10500
# image data/202410041747-new\10550.bmp fvalue 10550
# image data/202410041747-new\10600.bmp fvalue 10600
# image data/202410041747-new\10650.bmp fvalue 10650
# image data/202410041747-new\10700.bmp fvalue 10700
# image data/202410041747-new\10750.bmp fvalue 10750
# image data/202410041747-new\10800.bmp fvalue 10800
# image data/202410041747-new\10850.bmp fvalue 10850
# image data/202410041747-new\10900.bmp fvalue 10900
# image data/202410041747-new\10950.bmp fvalue 10950
# image data/202410041747-new\11000.bmp fvalue 11000
# image data/202410041747-new\11050.bmp fvalue 11050
# image data/202410041747-new\11100.bmp fvalue 11100
# image data/202410041747-new\11150.bmp fvalue 11150
# image data/202410041747-new\11200.bmp fvalue 11200
# image data/202410041747-new\11250.bmp fvalue 11250
# image data/202410041747-new\11300.bmp fvalue 11300
# image data/202410041747-new\11350.bmp fvalue 11350
# image data/202410041747-new\11400.bmp fvalue 11400
# image data/202410041747-new\11450.bmp fvalue 11450
# image data/202410041747-new\11500.bmp fvalue 11500
# image data/202410041747-new\11550.bmp fvalue 11550
# image data/202410041747-new\11600.bmp fvalue 11600
# image data/202410041747-new\11650.bmp fvalue 11650
# image data/202410041747-new\11700.bmp fvalue 11700
# image data/202410041747-new\11750.bmp fvalue 11750
# image data/202410041747-new\11800.bmp fvalue 11800
# image data/202410041747-new\11850.bmp fvalue 11850
# image data/202410041747-new\11900.bmp fvalue 11900
# image data/202410041747-new\11950.bmp fvalue 11950
# image data/202410041747-new\12000.bmp fvalue 12000
# image data/202410041747-new\12050.bmp fvalue 12050
# image data/202410041747-new\12100.bmp fvalue 12100
# image data/202410041747-new\12150.bmp fvalue 12150
# image data/202410041747-new\12200.bmp fvalue 12200
# image data/202410041747-new\12250.bmp fvalue 12250
# image data/202410041747-new\12300.bmp fvalue 12300
# image data/202410041747-new\12350.bmp fvalue 12350
# image data/202410041747-new\12400.bmp fvalue 12400
# image data/202410041747-new\12450.bmp fvalue 12450
# image data/202410041747-new\12500.bmp fvalue 12500
# image data/202410041747-new\12550.bmp fvalue 12550
# image data/202410041747-new\12600.bmp fvalue 12600
# image data/202410041747-new\12650.bmp fvalue 12650
# image data/202410041747-new\12700.bmp fvalue 12700
# image data/202410041747-new\12750.bmp fvalue 12750
# image data/202410041747-new\12800.bmp fvalue 12800
# image data/202410041747-new\12850.bmp fvalue 12850
# image data/202410041747-new\12900.bmp fvalue 12900
# image data/202410041747-new\12950.bmp fvalue 12950
# image data/202410041747-new\13000.bmp fvalue 13000
# image data/202410041747-new\13050.bmp fvalue 13050
# image data/202410041747-new\13100.bmp fvalue 13100
# image data/202410041747-new\13150.bmp fvalue 13150
# image data/202410041747-new\13200.bmp fvalue 13200
# image data/202410041747-new\13250.bmp fvalue 13250
# image data/202410041747-new\13300.bmp fvalue 13300
# image data/202410041747-new\13350.bmp fvalue 13350
# image data/202410041747-new\13400.bmp fvalue 13400
# image data/202410041747-new\13450.bmp fvalue 13450
# image data/202410041747-new\13500.bmp fvalue 13500
# image data/202410041747-new\13550.bmp fvalue 13550
# image data/202410041747-new\13600.bmp fvalue 13600
# image data/202410041747-new\13650.bmp fvalue 13650
# image data/202410041747-new\13700.bmp fvalue 13700
# image data/202410041747-new\13750.bmp fvalue 13750
# image data/202410041747-new\13800.bmp fvalue 13800
# image data/202410041747-new\13850.bmp fvalue 13850
# image data/202410041747-new\13900.bmp fvalue 13900
# image data/202410041747-new\13950.bmp fvalue 13950
# image data/202410041747-new\14000.bmp fvalue 14000
# image data/202410041747-new\14050.bmp fvalue 14050
# image data/202410041747-new\14100.bmp fvalue 14100
# image data/202410041747-new\14150.bmp fvalue 14150
# image data/202410041747-new\14200.bmp fvalue 14200
# image data/202410041747-new\14250.bmp fvalue 14250
# image data/202410041747-new\14300.bmp fvalue 14300
# image data/202410041747-new\14350.bmp fvalue 14350
# image data/202410041747-new\14400.bmp fvalue 14400
# image data/202410041747-new\14450.bmp fvalue 14450
# image data/202410041747-new\14500.bmp fvalue 14500
# image data/202410041747-new\14550.bmp fvalue 14550
# image data/202410041747-new\14600.bmp fvalue 14600
# image data/202410041747-new\14650.bmp fvalue 14650
# image data/202410041747-new\14700.bmp fvalue 14700
# image data/202410041747-new\14750.bmp fvalue 14750
# image data/202410041747-new\14800.bmp fvalue 14800
# image data/202410041747-new\14850.bmp fvalue 14850
# image data/202410041747-new\14900.bmp fvalue 14900
# image data/202410041747-new\14950.bmp fvalue 14950
# image data/202410041747-new\15000.bmp fvalue 15000
# image data/202410041747-new\15050.bmp fvalue 15050
# image data/202410041747-new\15100.bmp fvalue 15100
# image data/202410041747-new\15150.bmp fvalue 15150
# image data/202410041747-new\15200.bmp fvalue 15200
# image data/202410041747-new\15250.bmp fvalue 15250
# image data/202410041747-new\15300.bmp fvalue 15300
# image data/202410041747-new\15350.bmp fvalue 15350
# image data/202410041747-new\15400.bmp fvalue 15400
# image data/202410041747-new\15450.bmp fvalue 15450
# image data/202410041747-new\15500.bmp fvalue 15500
# image data/202410041747-new\15550.bmp fvalue 15550
# image data/202410041747-new\15600.bmp fvalue 15600
# image data/202410041747-new\15650.bmp fvalue 15650
# image data/202410041747-new\15700.bmp fvalue 15700
# image data/202410041747-new\15750.bmp fvalue 15750
# image data/202410041747-new\15800.bmp fvalue 15800
# image data/202410041747-new\15850.bmp fvalue 15850
# image data/202410041747-new\15900.bmp fvalue 15900
# image data/202410041747-new\15950.bmp fvalue 15950
# image data/202410041747-new\16000.bmp fvalue 16000
# image data/202410041747-new\16050.bmp fvalue 16050
# image data/202410041747-new\16100.bmp fvalue 16100
# image data/202410041747-new\16150.bmp fvalue 16150
# image data/202410041747-new\16200.bmp fvalue 16200
# image data/202410041747-new\16250.bmp fvalue 16250
# image data/202410041747-new\16300.bmp fvalue 16300
# image data/202410041747-new\16350.bmp fvalue 16350
# image data/202410041747-new\16400.bmp fvalue 16400
# image data/202410041747-new\16450.bmp fvalue 16450
# image data/202410041747-new\16500.bmp fvalue 16500
# image data/202410041747-new\16550.bmp fvalue 16550
# image data/202410041747-new\16600.bmp fvalue 16600
# image data/202410041747-new\16650.bmp fvalue 16650
# image data/202410041747-new\16700.bmp fvalue 16700
# image data/202410041747-new\16750.bmp fvalue 16750
# image data/202410041747-new\16800.bmp fvalue 16800
# image data/202410041747-new\16850.bmp fvalue 16850
# image data/202410041747-new\16900.bmp fvalue 16900
# image data/202410041747-new\16950.bmp fvalue 16950
# image data/202410041747-new\17000.bmp fvalue 17000
# image data/202410041747-new\17050.bmp fvalue 17050
# image data/202410041747-new\17100.bmp fvalue 17100
# image data/202410041747-new\17150.bmp fvalue 17150
# image data/202410041747-new\17200.bmp fvalue 17200
# image data/202410041747-new\17250.bmp fvalue 17250
# image data/202410041747-new\17300.bmp fvalue 17300
# image data/202410041747-new\17350.bmp fvalue 17350
# image data/202410041747-new\17400.bmp fvalue 17400
# image data/202410041747-new\17450.bmp fvalue 17450
# image data/202410041747-new\17500.bmp fvalue 17500
# image data/202410041747-new\17550.bmp fvalue 17550
# image data/202410041747-new\17600.bmp fvalue 17600
# image data/202410041747-new\17650.bmp fvalue 17650
# image data/202410041747-new\17700.bmp fvalue 17700
# image data/202410041747-new\17750.bmp fvalue 17750
# image data/202410041747-new\17800.bmp fvalue 17800
# image data/202410041747-new\17850.bmp fvalue 17850
# image data/202410041747-new\17900.bmp fvalue 17900
# image data/202410041747-new\17950.bmp fvalue 17950
# image data/202410041747-new\18000.bmp fvalue 18000
# image data/202410041747-new\18050.bmp fvalue 18050
# image data/202410041747-new\18100.bmp fvalue 18100
# image data/202410041747-new\18150.bmp fvalue 18150
# image data/202410041747-new\18200.bmp fvalue 18200
# image data/202410041747-new\18250.bmp fvalue 18250
# image data/202410041747-new\18300.bmp fvalue 18300
# image data/202410041747-new\18350.bmp fvalue 18350
# image data/202410041747-new\18400.bmp fvalue 18400
# image data/202410041747-new\18450.bmp fvalue 18450
# image data/202410041747-new\18500.bmp fvalue 18500
# image data/202410041747-new\18550.bmp fvalue 18550
# image data/202410041747-new\18600.bmp fvalue 18600
# image data/202410041747-new\18650.bmp fvalue 18650
# image data/202410041747-new\18700.bmp fvalue 18700
# image data/202410041747-new\18750.bmp fvalue 18750
# image data/202410041747-new\18800.bmp fvalue 18800
# image data/202410041747-new\18850.bmp fvalue 18850
# image data/202410041747-new\18900.bmp fvalue 18900
# image data/202410041747-new\18950.bmp fvalue 18950
# image data/202410041747-new\19000.bmp fvalue 19000
# image data/202410041747-new\19050.bmp fvalue 19050
# image data/202410041747-new\19100.bmp fvalue 19100
# image data/202410041747-new\19150.bmp fvalue 19150
# image data/202410041747-new\19200.bmp fvalue 19200
# image data/202410041747-new\19250.bmp fvalue 19250
# image data/202410041747-new\19300.bmp fvalue 19300
# image data/202410041747-new\19350.bmp fvalue 19350
# image data/202410041747-new\19400.bmp fvalue 19400
# image data/202410041747-new\19450.bmp fvalue 19450
# image data/202410041747-new\19500.bmp fvalue 19500
# image data/202410041747-new\19550.bmp fvalue 19550
# image data/202410041747-new\19600.bmp fvalue 19600
# image data/202410041747-new\19650.bmp fvalue 19650
# image data/202410041747-new\19700.bmp fvalue 19700
# image data/202410041747-new\19750.bmp fvalue 19750
# image data/202410041747-new\19800.bmp fvalue 19800
# image data/202410041747-new\19850.bmp fvalue 19850
# image data/202410041747-new\19900.bmp fvalue 19900
# image data/202410041747-new\19950.bmp fvalue 19950
# image data/202410041747-new\20000.bmp fvalue 20000
# image data/202410041747-new\20050.bmp fvalue 20050
# image data/202410041747-new\20100.bmp fvalue 20100
# image data/202410041747-new\20150.bmp fvalue 20150
# image data/202410041747-new\20200.bmp fvalue 20200
# image data/202410041747-new\20250.bmp fvalue 20250
# image data/202410041747-new\20300.bmp fvalue 20300
# image data/202410041747-new\20350.bmp fvalue 20350
# image data/202410041747-new\20400.bmp fvalue 20400
# image data/202410041747-new\20450.bmp fvalue 20450
# image data/202410041747-new\20500.bmp fvalue 20500
# image data/202410041747-new\20550.bmp fvalue 20550
# image data/202410041747-new\20600.bmp fvalue 20600
# image data/202410041747-new\20650.bmp fvalue 20650
# image data/202410041747-new\20700.bmp fvalue 20700
# image data/202410041747-new\20750.bmp fvalue 20750
# image data/202410041747-new\20800.bmp fvalue 20800
# image data/202410041747-new\20850.bmp fvalue 20850
# image data/202410041747-new\20900.bmp fvalue 20900
# image data/202410041747-new\20950.bmp fvalue 20950
# image data/202410041747-new\21000.bmp fvalue 21000
# image data/202410041747-new\21050.bmp fvalue 21050
# image data/202410041747-new\21100.bmp fvalue 21100
# image data/202410041747-new\21150.bmp fvalue 21150
# image data/202410041747-new\21200.bmp fvalue 21200
# image data/202410041747-new\21250.bmp fvalue 21250
# image data/202410041747-new\21300.bmp fvalue 21300
# image data/202410041747-new\21350.bmp fvalue 21350
# image data/202410041747-new\21400.bmp fvalue 21400
# image data/202410041747-new\21450.bmp fvalue 21450
# image data/202410041747-new\21500.bmp fvalue 21500
# image data/202410041747-new\21550.bmp fvalue 21550
# image data/202410041747-new\21600.bmp fvalue 21600
# image data/202410041747-new\21650.bmp fvalue 21650
# image data/202410041747-new\21700.bmp fvalue 21700
# image data/202410041747-new\21750.bmp fvalue 21750
# image data/202410041747-new\21800.bmp fvalue 21800
# image data/202410041747-new\21850.bmp fvalue 21850
# image data/202410041747-new\21900.bmp fvalue 21900
# image data/202410041747-new\21950.bmp fvalue 21950
# image data/202410041747-new\22000.bmp fvalue 22000
# image data/202410041747-new\22050.bmp fvalue 22050
# image data/202410041747-new\22100.bmp fvalue 22100
# image data/202410041747-new\22150.bmp fvalue 22150
# image data/202410041747-new\22200.bmp fvalue 22200
# image data/202410041747-new\22250.bmp fvalue 22250
# image data/202410041747-new\22300.bmp fvalue 22300
# image data/202410041747-new\22350.bmp fvalue 22350
# image data/202410041747-new\22400.bmp fvalue 22400
# image data/202410041747-new\22450.bmp fvalue 22450
# image data/202410041747-new\22500.bmp fvalue 22500
# image data/202410041747-new\22550.bmp fvalue 22550
# image data/202410041747-new\22600.bmp fvalue 22600
# image data/202410041747-new\22650.bmp fvalue 22650
# image data/202410041747-new\22700.bmp fvalue 22700
# image data/202410041747-new\22750.bmp fvalue 22750
# image data/202410041747-new\22800.bmp fvalue 22800
# image data/202410041747-new\22850.bmp fvalue 22850
# image data/202410041747-new\22900.bmp fvalue 22900
# image data/202410041747-new\22950.bmp fvalue 22950
# image data/202410041747-new\23000.bmp fvalue 23000
# image data/202410041747-new\23050.bmp fvalue 23050
# image data/202410041747-new\23100.bmp fvalue 23100
# image data/202410041747-new\23150.bmp fvalue 23150
# image data/202410041747-new\23200.bmp fvalue 23200
# image data/202410041747-new\23250.bmp fvalue 23250
# image data/202410041747-new\23300.bmp fvalue 23300
# image data/202410041747-new\23350.bmp fvalue 23350
# image data/202410041747-new\23400.bmp fvalue 23400
# image data/202410041747-new\23450.bmp fvalue 23450
# image data/202410041747-new\23500.bmp fvalue 23500
# image data/202410041747-new\23550.bmp fvalue 23550
# image data/202410041747-new\23600.bmp fvalue 23600
# image data/202410041747-new\23650.bmp fvalue 23650
# image data/202410041747-new\23700.bmp fvalue 23700
# image data/202410041747-new\23750.bmp fvalue 23750
# image data/202410041747-new\23800.bmp fvalue 23800
# image data/202410041747-new\23850.bmp fvalue 23850
# image data/202410041747-new\23900.bmp fvalue 23900
# image data/202410041747-new\23950.bmp fvalue 23950
# image data/202410041747-new\24000.bmp fvalue 24000
# image data/202410041747-new\24050.bmp fvalue 24050
# image data/202410041747-new\24100.bmp fvalue 24100
# image data/202410041747-new\24150.bmp fvalue 24150
# image data/202410041747-new\24200.bmp fvalue 24200
# image data/202410041747-new\24250.bmp fvalue 24250
# image data/202410041747-new\24300.bmp fvalue 24300
# image data/202410041747-new\24350.bmp fvalue 24350
# image data/202410041747-new\24400.bmp fvalue 24400
# image data/202410041747-new\24450.bmp fvalue 24450
# image data/202410041747-new\24500.bmp fvalue 24500
# image data/202410041747-new\24550.bmp fvalue 24550
# image data/202410041747-new\24600.bmp fvalue 24600
# image data/202410041747-new\24650.bmp fvalue 24650
# image data/202410041747-new\24700.bmp fvalue 24700
# image data/202410041747-new\24750.bmp fvalue 24750
# image data/202410041747-new\24800.bmp fvalue 24800
# image data/202410041747-new\24850.bmp fvalue 24850
# image data/202410041747-new\24900.bmp fvalue 24900
# image data/202410041747-new\24950.bmp fvalue 24950
# image data/202410041747-new\25000.bmp fvalue 25000
# image data/202410041747-new\25050.bmp fvalue 25050
# image data/202410041747-new\25100.bmp fvalue 25100
# image data/202410041747-new\25150.bmp fvalue 25150
# image data/202410041747-new\25200.bmp fvalue 25200
# image data/202410041747-new\25250.bmp fvalue 25250
# image data/202410041747-new\25300.bmp fvalue 25300
# image data/202410041747-new\25350.bmp fvalue 25350
# image data/202410041747-new\25400.bmp fvalue 25400
# image data/202410041747-new\25450.bmp fvalue 25450
# image data/202410041747-new\25500.bmp fvalue 25500
# image data/202410041747-new\25550.bmp fvalue 25550
# image data/202410041747-new\25600.bmp fvalue 25600
# image data/202410041747-new\25650.bmp fvalue 25650
# image data/202410041747-new\25700.bmp fvalue 25700
# image data/202410041747-new\25750.bmp fvalue 25750
# image data/202410041747-new\25800.bmp fvalue 25800
# image data/202410041747-new\25850.bmp fvalue 25850
# image data/202410041747-new\25900.bmp fvalue 25900
# image data/202410041747-new\25950.bmp fvalue 25950
# image data/202410041747-new\26000.bmp fvalue 26000
# image data/202410041747-new\26050.bmp fvalue 26050
# image data/202410041747-new\26100.bmp fvalue 26100
# image data/202410041747-new\26150.bmp fvalue 26150
# image data/202410041747-new\26200.bmp fvalue 26200
# image data/202410041747-new\26250.bmp fvalue 26250
# image data/202410041747-new\26300.bmp fvalue 26300
# image data/202410041747-new\26350.bmp fvalue 26350
# image data/202410041747-new\26400.bmp fvalue 26400
# image data/202410041747-new\26450.bmp fvalue 26450
# image data/202410041747-new\26500.bmp fvalue 26500
# image data/202410041747-new\26550.bmp fvalue 26550
# image data/202410041747-new\26600.bmp fvalue 26600
# image data/202410041747-new\26650.bmp fvalue 26650
# image data/202410041747-new\26700.bmp fvalue 26700
# image data/202410041747-new\26750.bmp fvalue 26750
# image data/202410041747-new\26800.bmp fvalue 26800
# image data/202410041747-new\26850.bmp fvalue 26850
# image data/202410041747-new\26900.bmp fvalue 26900
# image data/202410041747-new\26950.bmp fvalue 26950
# image data/202410041747-new\27000.bmp fvalue 27000
# image data/202410041747-new\27050.bmp fvalue 27050
# image data/202410041747-new\27100.bmp fvalue 27100
# image data/202410041747-new\27150.bmp fvalue 27150
# image data/202410041747-new\27200.bmp fvalue 27200
# image data/202410041747-new\27250.bmp fvalue 27250
# image data/202410041747-new\27300.bmp fvalue 27300
# image data/202410041747-new\27350.bmp fvalue 27350
# image data/202410041747-new\27400.bmp fvalue 27400
# image data/202410041747-new\27450.bmp fvalue 27450
# image data/202410041747-new\27500.bmp fvalue 27500
# image data/202410041747-new\27550.bmp fvalue 27550
# image data/202410041747-new\27600.bmp fvalue 27600
# image data/202410041747-new\27650.bmp fvalue 27650
# image data/202410041747-new\27700.bmp fvalue 27700
# image data/202410041747-new\27750.bmp fvalue 27750
# image data/202410041747-new\27800.bmp fvalue 27800
# image data/202410041747-new\27850.bmp fvalue 27850
# image data/202410041747-new\27900.bmp fvalue 27900
# image data/202410041747-new\27950.bmp fvalue 27950
# image data/202410041747-new\28000.bmp fvalue 28000
# image data/202410041747-new\28050.bmp fvalue 28050
# image data/202410041747-new\28100.bmp fvalue 28100
# image data/202410041747-new\28150.bmp fvalue 28150
# image data/202410041747-new\28200.bmp fvalue 28200
# image data/202410041747-new\28250.bmp fvalue 28250
# image data/202410041747-new\28300.bmp fvalue 28300
# image data/202410041747-new\28350.bmp fvalue 28350
# image data/202410041747-new\28400.bmp fvalue 28400
# image data/202410041747-new\28450.bmp fvalue 28450
# image data/202410041747-new\28500.bmp fvalue 28500
# image data/202410041747-new\28550.bmp fvalue 28550
# image data/202410041747-new\28600.bmp fvalue 28600
# image data/202410041747-new\28650.bmp fvalue 28650
# image data/202410041747-new\28700.bmp fvalue 28700
# image data/202410041747-new\28750.bmp fvalue 28750
# image data/202410041747-new\28800.bmp fvalue 28800
# image data/202410041747-new\28850.bmp fvalue 28850
# image data/202410041747-new\28900.bmp fvalue 28900
# image data/202410041747-new\28950.bmp fvalue 28950
# image data/202410041747-new\29000.bmp fvalue 29000
# image data/202410041747-new\29050.bmp fvalue 29050
# image data/202410041747-new\29100.bmp fvalue 29100
# image data/202410041747-new\29150.bmp fvalue 29150
# image data/202410041747-new\29200.bmp fvalue 29200
# image data/202410041747-new\29250.bmp fvalue 29250
# image data/202410041747-new\29300.bmp fvalue 29300
# image data/202410041747-new\29350.bmp fvalue 29350
# image data/202410041747-new\29400.bmp fvalue 29400
# image data/202410041747-new\29450.bmp fvalue 29450
# image data/202410041747-new\29500.bmp fvalue 29500
# image data/202410041747-new\29550.bmp fvalue 29550
# image data/202410041747-new\29600.bmp fvalue 29600
# image data/202410041747-new\29650.bmp fvalue 29650
# image data/202410041747-new\29700.bmp fvalue 29700
# image data/202410041747-new\29750.bmp fvalue 29750
# image data/202410041747-new\29800.bmp fvalue 29800
# image data/202410041747-new\29850.bmp fvalue 29850
# image data/202410041747-new\29900.bmp fvalue 29900
# image data/202410041747-new\29950.bmp fvalue 29950
# image data/202410041747-new\30000.bmp fvalue 30000

# %%
    # コントラストの最大値を奥行きとする．depth_index = 画像，depth = フォーカス値
    cvalues = np.stack(cvalues)
    depth_index = np.argmax(cvalues,axis=0)
    depth = depth_index.astype("uint64")
    for i in range(len(cvalues)):
        depth[np.where(depth == i)] = fvalues[i]

# %%
    # 保存する
    fname = os.path.join(DIR,"index.bmp")
    cv2.imwrite(fname, depth_index)
    fname = os.path.join(DIR,"depth.bmp")
    cv2.imwrite(fname, depth)
# Out:
# True

# %%
    plt.hist(depth)
# Out:
# (array([[  0.,   0.,   0., ...,   0.,   7., 121.],
#         [  0.,   0.,   0., ...,   0.,   0., 124.],
#         [  0.,   0.,   0., ...,   0.,   0., 109.],
#         ...,
#         [  4.,   0.,   0., ...,   0.,   0.,   6.],
#         [  5.,   0.,   2., ...,   0.,   0.,   5.],
#         [  4.,   0.,   4., ...,   0.,   0.,   4.]]),
#  array([10050., 12045., 14040., 16035., 18030., 20025., 22020., 24015.,
#         26010., 28005., 30000.]),
#  <a list of 307 BarContainer objects>)

# %%
    plt.imshow(depth)

# %%
    #元画像
    fname = os.path.join(DIR,'00200.bmp')
    im = cv2.imread(fname)
    im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
    plt.imshow(im)

# %%
    depth2 = depth
    THRESH = 22000
    depth2[np.where(depth2 > THRESH)] = 0
    plt.imshow(depth2)
